# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import api_keys
import random
import gmaps
import json
import os
import re

# Import API key and tools
from sklearn.linear_model import LinearRegression
from scipy.stats import linregress
from api_keys import weather_api_key
from citipy import citipy
from pprint import pprint
from scipy import stats

# %% [markdown]
# ## Generate Cities List

# %%
#Generate range
lat_range = (-90, 90)
lng_range = (-180, 180)

# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
        city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
        city = city.replace(" ", "%20")
    
    # If the city is unique, then add it to a our cities list
        if city not in cities:
            cities.append(city)

# %%
# Print the city count to confirm sufficient count
len(weather_df)
# Out:
# 586

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key 

# Save config information
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []
record = 1

print(f"Beginning Data Retrieval")
print(f"-------------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------

# %%
# Loop through the list of cities and perform a request
for city in cities:  
    try: 
        response = requests.get(f"{url}&q={city}").json() 
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record} | {city_record}")
        print(f"{url}&q={city}")
        
        # Increase counter by one 
        record= record + 1
        
        
    # If no record found "skip" to next call
    except:
        print("City not found. Skipping...")
    continue
# Out:
# Processing Record 1 | Hokitika
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=hokitika
# Processing Record 2 | Busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=busselton
# Processing Record 3 | Kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=kavieng
# Processing Record 4 | Cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=cidreira
# Processing Record 5 | Camacha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=camacha
# Processing Record 6 | Hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=hasaki
# Processing Record 7 | Charagua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=charagua
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 8 | Castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=castro
# Processing Record 9 | Rio Grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=rio%20grande
# Processing Record 10 | Ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=ushuaia
# Processing Record 11 | Broome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=broome
# City not found. Skipping...
# Processing Record 12 | Kroya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=kroya
# Processing Record 13 | Atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=atuona
# Processing Record 14 | Straumen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=straumen
# Processing Record 15 | Longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=longyearbyen
# Processing Record 16 | Martinópolis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=martinopolis
# Processing Record 17 | Santa Cruz Cabrália
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=santa%20cruz%20cabralia
# Processing Record 18 | Great Yarmouth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=great%20yarmouth
# Processing Record 19 | São Filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=sao%20filipe
# Processing Record 20 | Punta Arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=punta%20arenas
# Processing Record 21 | George Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=georgetown
# Processing Record 22 | Saint Paul Harbor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=kodiak
# Processing Record 23 | Semirara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=semirara
# Processing Record 24 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=jamestown
# City not found. Skipping...
# Processing Record 25 | Saint-Philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=saint-philippe
# Processing Record 26 | Shingū
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=shingu
# Processing Record 27 | Mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=mataura
# Processing Record 28 | Mar del Plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=mar%20del%20plata
# Processing Record 29 | Belaya Gora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=belaya%20gora
# City not found. Skipping...
# Processing Record 30 | Port Alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=port%20alfred
# Processing Record 31 | Rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=rikitea
# Processing Record 32 | Stykkisholmur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=stykkisholmur
# Processing Record 33 | Morondava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=morondava
# City not found. Skipping...
# Processing Record 34 | Katobu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=katobu
# City not found. Skipping...
# Processing Record 35 | Husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=husavik
# Processing Record 36 | Poya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=poya
# Processing Record 37 | Narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=narsaq
# Processing Record 38 | Mount Gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=mount%20gambier
# Processing Record 39 | Hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=hilo
# Processing Record 40 | Bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=bluff
# Processing Record 41 | Itupiranga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=itupiranga
# Processing Record 42 | Clyde River
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=clyde%20river
# Processing Record 43 | Bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=bethel
# Processing Record 44 | Tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=tuktoyaktuk
# Processing Record 45 | São Félix do Xingu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=sao%20felix%20do%20xingu
# Processing Record 46 | Albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=albany
# Processing Record 47 | Fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=fortuna
# Processing Record 48 | Caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=caravelas
# Processing Record 49 | Chapais
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=chapais
# Processing Record 50 | Bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=bredasdorp
# Processing Record 51 | Deputatsky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=deputatskiy
# Processing Record 52 | Esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=esperance
# Processing Record 53 | Kushnarenkovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=kushnarenkovo
# Processing Record 54 | Mehamn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=mehamn
# Processing Record 55 | Fallon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=fallon
# Processing Record 56 | Sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=sitka
# Processing Record 57 | Mahon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=mao
# Processing Record 58 | Provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=provideniya
# Processing Record 59 | Ialibu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=ialibu
# Processing Record 60 | Geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=geraldton
# Processing Record 61 | Hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=hermanus
# Processing Record 62 | Severo-Kuril'sk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=severo-kurilsk
# Processing Record 63 | Carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=carnarvon
# Processing Record 64 | Yefremov
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=yefremov
# Processing Record 65 | East London
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=east%20london
# Processing Record 66 | Tyrma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=tyrma
# Processing Record 67 | Katangli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=katangli
# Processing Record 68 | Puerto Colombia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=puerto%20colombia
# Processing Record 69 | Lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=lebu
# Processing Record 70 | Qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=qaanaaq
# Processing Record 71 | Ribeira Grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=ribeira%20grande
# Processing Record 72 | Havre-St-Pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=havre-saint-pierre
# City not found. Skipping...
# Processing Record 73 | Khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=khatanga
# Processing Record 74 | Moranbah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=moranbah
# Processing Record 75 | Bhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=bhan
# Processing Record 76 | Namatanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=namatanai
# Processing Record 77 | Gornopravdinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=gornopravdinsk
# Processing Record 78 | Margate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=margate
# Processing Record 79 | Kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=kahului
# City not found. Skipping...
# Processing Record 80 | Souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=souillac
# Processing Record 81 | Eydhafushi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=eydhafushi
# Processing Record 82 | Bubaque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=bubaque
# Processing Record 83 | Urengoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=urengoy
# Processing Record 84 | Nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=nikolskoye
# Processing Record 85 | Suksun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=suksun
# Processing Record 86 | Tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=tiksi
# City not found. Skipping...
# Processing Record 87 | Coahuayana Viejo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=coahuayana
# Processing Record 88 | Nyimba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=nyimba
# Processing Record 89 | Hong Kong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=victoria
# Processing Record 90 | Mamakan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=mamakan
# Processing Record 91 | Araouane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=araouane
# Processing Record 92 | Poço Verde
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=poco%20verde
# Processing Record 93 | Dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=dikson
# Processing Record 94 | Hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=hithadhoo
# Processing Record 95 | Ofakim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=ofaqim
# Processing Record 96 | Butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=butaritari
# Processing Record 97 | Tura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=tura
# Processing Record 98 | Namie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=namie
# Processing Record 99 | Buchanan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=buchanan
# Processing Record 100 | Hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=hobart
# Processing Record 101 | Makassar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=makasar
# Processing Record 102 | Warrnambool
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=warrnambool
# Processing Record 103 | Avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=avarua
# Processing Record 104 | Coracora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=coracora
# Processing Record 105 | Nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=nome
# Processing Record 106 | Kutum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=kutum
# Processing Record 107 | Kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=kavaratti
# Processing Record 108 | Iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=iqaluit
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 109 | Talara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=talara
# Processing Record 110 | Truro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=truro
# Processing Record 111 | Vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=vaini
# Processing Record 112 | Guerrero Negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=guerrero%20negro
# Processing Record 113 | Sungai Penuh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=sungaipenuh
# Processing Record 114 | San Luis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=san%20luis
# Processing Record 115 | San Miguel de Tucumán
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=tucuman
# Processing Record 116 | Nago
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=nago
# Processing Record 117 | Inuvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=inuvik
# Processing Record 118 | Sabha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=sabha
# Processing Record 119 | San Bartolomé de Tirajana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=san%20bartolome%20de%20tirajana
# Processing Record 120 | Kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=kapaa
# Processing Record 121 | Cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=cherskiy
# Processing Record 122 | Paamiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=paamiut
# Processing Record 123 | Pacific Grove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=pacific%20grove
# Processing Record 124 | Tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=tuatapere
# Processing Record 125 | Kiruna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=kiruna
# City not found. Skipping...
# Processing Record 126 | Saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=saskylakh
# Processing Record 127 | Kushiro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=kushiro
# Processing Record 128 | Comodoro Rivadavia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=comodoro%20rivadavia
# City not found. Skipping...
# Processing Record 129 | Quesnel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=quesnel
# Processing Record 130 | Porbandar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=porbandar
# Processing Record 131 | Yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=yellowknife
# City not found. Skipping...
# Processing Record 132 | Sumbe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=sumbe
# Processing Record 133 | Matagami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=matagami
# Processing Record 134 | Ürümqi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=urumqi
# Processing Record 135 | Katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=katsuura
# Processing Record 136 | Port Lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=port%20lincoln
# Processing Record 137 | Hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=hambantota
# Processing Record 138 | Tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=tasiilaq
# Processing Record 139 | Barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=barrow
# Processing Record 140 | Cape Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=cape%20town
# Processing Record 141 | Bawku
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=bawku
# Processing Record 142 | Kenora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=kenora
# Processing Record 143 | Cockburn Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=cockburn%20town
# Processing Record 144 | Bukama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=bukama
# Processing Record 145 | Liverpool
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=liverpool
# Processing Record 146 | Airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=airai
# Processing Record 147 | Saint George
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=saint%20george
# Processing Record 148 | Kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=kaitangata
# Processing Record 149 | Upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=upernavik
# Processing Record 150 | Yar-Sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=yar-sale
# Processing Record 151 | Noumea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=noumea
# Processing Record 152 | Omsukchan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=omsukchan
# City not found. Skipping...
# Processing Record 153 | Puerto Ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=puerto%20ayora
# Processing Record 154 | Władysławowo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=wladyslawowo
# Processing Record 155 | Yārāda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=yarada
# Processing Record 156 | Concordia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=concordia
# Processing Record 157 | Kiunga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=kiunga
# Processing Record 158 | Phalaborwa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=phalaborwa
# Processing Record 159 | Nara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=nara
# Processing Record 160 | Maţāy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=matay
# Processing Record 161 | Oltu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=oltu
# Processing Record 162 | Bumba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=bumba
# Processing Record 163 | Ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=ahipara
# Processing Record 164 | San Andrés
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=san%20andres
# Processing Record 165 | Mata de Plátano
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=mata%20de%20platano
# Processing Record 166 | Bondo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=bondo
# Processing Record 167 | Alice Springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=alice%20springs
# Processing Record 168 | Vanimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=vanimo
# Processing Record 169 | Robertsport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=robertsport
# City not found. Skipping...
# Processing Record 170 | Kuching
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=kuching
# Processing Record 171 | Klaksvík
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=klaksvik
# Processing Record 172 | Balabac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=balabac
# Processing Record 173 | Luang Prabang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=luang%20prabang
# Processing Record 174 | Vila Franca do Campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=vila%20franca%20do%20campo
# Processing Record 175 | Sibolga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=sibolga
# Processing Record 176 | Mahébourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=mahebourg
# Processing Record 177 | Torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=torbay
# Processing Record 178 | Kichera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=kichera
# Processing Record 179 | Westport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=westport
# Processing Record 180 | Northam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=northam
# Processing Record 181 | Hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=hofn
# Processing Record 182 | Pimentel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=pimentel
# Processing Record 183 | Lapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=lapa
# Processing Record 184 | New Norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=new%20norfolk
# Processing Record 185 | Harper
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=harper
# Processing Record 186 | Jilavele
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=jilavele
# Processing Record 187 | Yeppoon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=yeppoon
# Processing Record 188 | Aketi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=aketi
# Processing Record 189 | Rocha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=rocha
# Processing Record 190 | Sterling
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=sterling
# Processing Record 191 | Bantogon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=bantogon
# Processing Record 192 | Port Hardy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=port%20hardy
# Processing Record 193 | Yangi Marg`ilon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=komsomolskiy
# Processing Record 194 | Sambava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=sambava
# Processing Record 195 | Akureyri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=akureyri
# Processing Record 196 | Pochutla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=pochutla
# Processing Record 197 | Bristol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=bristol
# Processing Record 198 | Nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=nanortalik
# Processing Record 199 | Labuhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=labuhan
# Processing Record 200 | Port Elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=port%20elizabeth
# Processing Record 201 | Maceió
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=maceio
# Processing Record 202 | Bud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=bud
# Processing Record 203 | Arrondissement d'Arcachon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=arcachon
# Processing Record 204 | Muros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=muros
# Processing Record 205 | Birnin Kebbi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=birnin%20kebbi
# Processing Record 206 | Sri Aman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=sri%20aman
# City not found. Skipping...
# Processing Record 207 | Tonj
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=tonj
# Processing Record 208 | San Quintín
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=san%20quintin
# Processing Record 209 | Port Hawkesbury
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=port%20hawkesbury
# Processing Record 210 | Grand Gaube
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=grand%20gaube
# Processing Record 211 | Bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=bengkulu
# Processing Record 212 | Ngunguru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=ngunguru
# Processing Record 213 | Bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=bandarbeyla
# City not found. Skipping...
# Processing Record 214 | Kieta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=kieta
# Processing Record 215 | Santa Lucía
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=santa%20lucia
# Processing Record 216 | Kassala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=kassala
# Processing Record 217 | Constitución
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=constitucion
# Processing Record 218 | Nichinan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=nichinan
# Processing Record 219 | Ilebo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=ilebo
# Processing Record 220 | Baoding
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=baoding
# Processing Record 221 | Inta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=inta
# Processing Record 222 | Kemijärvi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=kemijarvi
# Processing Record 223 | Codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=codrington
# City not found. Skipping...
# Processing Record 224 | Berlin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=berlin
# Processing Record 225 | Aquiraz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=aquiraz
# Processing Record 226 | Dibulla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=dibulla
# Processing Record 227 | Yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=yulara
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 228 | Wajima
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=wajima
# Processing Record 229 | Damietta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=damietta
# Processing Record 230 | Marsabit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=marsabit
# Processing Record 231 | High Level
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=high%20level
# Processing Record 232 | Salinópolis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=salinopolis
# Processing Record 233 | Puerto Baquerizo Moreno
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=puerto%20baquerizo%20moreno
# Processing Record 234 | Vostok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=vostok
# Processing Record 235 | Angoche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=angoche
# Processing Record 236 | Cabo Frio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=cabo%20frio
# Processing Record 237 | Thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=thompson
# Processing Record 238 | Carballo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=carballo
# Processing Record 239 | Portland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=portland
# City not found. Skipping...
# Processing Record 240 | Norman Wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=norman%20wells
# Processing Record 241 | Kununurra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=kununurra
# Processing Record 242 | Avera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=avera
# Processing Record 243 | Baltasi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=baltasi
# Processing Record 244 | Thinadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=thinadhoo
# Processing Record 245 | Pemangkat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=pemangkat
# Processing Record 246 | Mana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=mana
# Processing Record 247 | Savonlinna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=savonlinna
# City not found. Skipping...
# Processing Record 248 | Nelson Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=nelson%20bay
# Processing Record 249 | Meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=meulaboh
# Processing Record 250 | Qrendi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=qrendi
# Processing Record 251 | Porto Seguro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=porto%20seguro
# Processing Record 252 | Naze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=naze
# Processing Record 253 | Pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=pevek
# City not found. Skipping...
# Processing Record 254 | Bella Vista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=bella%20vista
# Processing Record 255 | Samarai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=samarai
# Processing Record 256 | Grand Baie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=grand%20baie
# Processing Record 257 | Jamame
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=jamame
# Processing Record 258 | Taltal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=taltal
# Processing Record 259 | Maniitsoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=maniitsoq
# Processing Record 260 | Kumluca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=kumluca
# Processing Record 261 | Dzhebariki-Khaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=dzhebariki-khaya
# Processing Record 262 | Mandurah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=mandurah
# Processing Record 263 | Mount Isa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=mount%20isa
# Processing Record 264 | Hirara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=hirara
# City not found. Skipping...
# Processing Record 265 | Kāmākhyānagar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=kamakhyanagar
# Processing Record 266 | Santa Rosa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=santa%20rosa
# Processing Record 267 | Quelimane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=quelimane
# Processing Record 268 | Mapimí
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=mapimi
# Processing Record 269 | Lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=lompoc
# Processing Record 270 | Ulladulla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=ulladulla
# Processing Record 271 | Arrondissement de Clermont
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=clermont
# Processing Record 272 | Buin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=buin
# Processing Record 273 | Manaus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=manaus
# Processing Record 274 | Kushmurun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=kushmurun
# Processing Record 275 | Stawell
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=stawell
# Processing Record 276 | Halifax
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=halifax
# Processing Record 277 | Beloha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=beloha
# Processing Record 278 | Filimonovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=filimonovo
# Processing Record 279 | Los Llanos de Aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=los%20llanos%20de%20aridane
# Processing Record 280 | Conde
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=conde
# Processing Record 281 | Berlevåg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=berlevag
# Processing Record 282 | Olafsvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=olafsvik
# Processing Record 283 | Nabire
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=nabire
# Processing Record 284 | Bayir
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=bayir
# Processing Record 285 | Igarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=igarka
# Processing Record 286 | Goiatuba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=goiatuba
# Processing Record 287 | Bambous Virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=bambous%20virieux
# Processing Record 288 | Buala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=buala
# Processing Record 289 | Ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=ilulissat
# Processing Record 290 | Te Anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=te%20anau
# Processing Record 291 | Saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=saldanha
# Processing Record 292 | Singleton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=singleton
# Processing Record 293 | Faya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=faya
# Processing Record 294 | Belyy Yar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=belyy%20yar
# Processing Record 295 | Barra de Tecoanapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=tecoanapa
# Processing Record 296 | Boundiali
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=boundiali
# Processing Record 297 | Vangaindrano
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=vangaindrano
# Processing Record 298 | Lao Cai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=lao%20cai
# Processing Record 299 | Saravan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=saravan
# Processing Record 300 | Mbaïki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=mbaiki
# Processing Record 301 | Aubenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=aubenas
# Processing Record 302 | Eskilstuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=eskilstuna
# Processing Record 303 | Dembī Dolo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=dembi%20dolo
# Processing Record 304 | Jaciara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=jaciara
# Processing Record 305 | Luganville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=luganville
# City not found. Skipping...
# Processing Record 306 | Kiryat Gat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=gat
# Processing Record 307 | Pilar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=pilar
# Processing Record 308 | Mossamedes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=namibe
# Processing Record 309 | Saint-Pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=saint-pierre
# Processing Record 310 | Huarmey
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=huarmey
# Processing Record 311 | Madingou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=madingou
# Processing Record 312 | Forio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=forio
# Processing Record 313 | Ankang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=ankang
# Processing Record 314 | Vernon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=vernon
# Processing Record 315 | Lodwar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=lodwar
# Processing Record 316 | Koutsouras
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=koutsouras
# Processing Record 317 | Custoias
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=custoias
# Processing Record 318 | A Coruña
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=a%20coruna
# Processing Record 319 | Bhachāu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=bhachau
# Processing Record 320 | Half Moon Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=half%20moon%20bay
# Processing Record 321 | Lüderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=luderitz
# Processing Record 322 | Manzhouli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=manzhouli
# Processing Record 323 | Chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=chokurdakh
# Processing Record 324 | Chake Chake
# ...
# Processing Record 480 | Baruun-Urt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=baruun-urt
# Processing Record 481 | Orzhytsya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=orzhytsya
# Processing Record 482 | Arlit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=arlit
# Processing Record 483 | Honningsvåg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=honningsvag
# Processing Record 484 | Saint-François
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=saint-francois
# Processing Record 485 | Sompeta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=sompeta
# Processing Record 486 | Pankovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=pankovka
# Processing Record 487 | Havøysund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=havoysund
# Processing Record 488 | Annecy-le-Vieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=annecy-le-vieux
# Processing Record 489 | Pākāla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=pakala
# Processing Record 490 | Sydney
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=sydney
# Processing Record 491 | Kirkwall
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=kirkwall
# Processing Record 492 | Orange Cove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=orange%20cove
# Processing Record 493 | Reinbek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=reinbek
# Processing Record 494 | Cotonou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=cotonou
# Processing Record 495 | Trincomalee
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=trincomalee
# Processing Record 496 | Butajīra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=butajira
# Processing Record 497 | Shache
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=shache
# Processing Record 498 | Kano
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=kano
# Processing Record 499 | Sabla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=sabla
# Processing Record 500 | Atikokan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=atikokan
# Processing Record 501 | Araguaçu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=araguacu
# Processing Record 502 | Baykit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=baykit
# Processing Record 503 | Verkhoyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=verkhoyansk
# Processing Record 504 | Port Shepstone
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=port%20shepstone
# Processing Record 505 | Zimmi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=zimmi
# Processing Record 506 | Lukoyanov
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=lukoyanov
# Processing Record 507 | Rokupr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=rokupr
# Processing Record 508 | Maltahöhe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=maltahohe
# Processing Record 509 | Srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=srednekolymsk
# Processing Record 510 | Kanniyākumāri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=kanniyakumari
# Processing Record 511 | Tuy Hoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=tuy%20hoa
# Processing Record 512 | Mattru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=mattru
# Processing Record 513 | San Cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=san%20cristobal
# Processing Record 514 | Kangaatsiaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=kangaatsiaq
# Processing Record 515 | Sisimiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=sisimiut
# Processing Record 516 | Polis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=polis
# Processing Record 517 | Azare
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=azare
# Processing Record 518 | Vorgashor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=vorgashor
# Processing Record 519 | Santa Isabel Rio Negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=santa%20isabel%20do%20rio%20negro
# Processing Record 520 | Coari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=coari
# Processing Record 521 | Okhotsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=okhotsk
# Processing Record 522 | Pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=pisco
# City not found. Skipping...
# Processing Record 523 | Dicabisagan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=dicabisagan
# Processing Record 524 | Wuwei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=wuwei
# Processing Record 525 | Ucluelet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=ucluelet
# Processing Record 526 | Calama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=calama
# Processing Record 527 | Tenabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=tenabo
# Processing Record 528 | Chui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=chuy
# Processing Record 529 | Ambositra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=ambositra
# Processing Record 530 | Tutóia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=tutoia
# Processing Record 531 | Yatou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=yatou
# Processing Record 532 | Malakal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=malakal
# Processing Record 533 | Kuznechikha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=kuznechikha
# Processing Record 534 | Rāmhormoz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=ramhormoz
# Processing Record 535 | Mizdah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=mizdah
# Processing Record 536 | Kumul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=hami
# Processing Record 537 | Trairi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=trairi
# Processing Record 538 | Olivença
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=olivenca
# Processing Record 539 | Dalvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=dalvik
# Processing Record 540 | Muli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=muli
# Processing Record 541 | Virginia Beach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=virginia%20beach
# Processing Record 542 | Port-Cartier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=port-cartier
# Processing Record 543 | Strezhevoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=strezhevoy
# Processing Record 544 | Hervey Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=hervey%20bay
# Processing Record 545 | Mauá
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=maua
# City not found. Skipping...
# Processing Record 546 | Lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=lorengau
# Processing Record 547 | Lolodorf
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=lolodorf
# Processing Record 548 | Khor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=khor
# City not found. Skipping...
# Processing Record 549 | Bitung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=bitung
# Processing Record 550 | Kalmunai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=kalmunai
# Processing Record 551 | Henties Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=henties%20bay
# Processing Record 552 | Pechenga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=pechenga
# City not found. Skipping...
# Processing Record 553 | Narasapuram
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=narasapur
# Processing Record 554 | Siklós
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=siklos
# Processing Record 555 | Mabaruma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=mabaruma
# Processing Record 556 | Matara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=matara
# Processing Record 557 | Savannah Bight
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=savannah%20bight
# Processing Record 558 | Tegul'det
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=teguldet
# Processing Record 559 | Ajdabiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=ajdabiya
# Processing Record 560 | Calabozo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=calabozo
# Processing Record 561 | Saryozek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=saryozek
# City not found. Skipping...
# Processing Record 562 | Gizo Government Station
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=gizo
# Processing Record 563 | Refojos de Basto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=refojos%20de%20basto
# City not found. Skipping...
# Processing Record 564 | Swan Hill
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=swan%20hill
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 565 | Rožňava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=roznava
# City not found. Skipping...
# Processing Record 566 | João Pinheiro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=joao%20pinheiro
# Processing Record 567 | Vuktyl
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=vuktyl
# Processing Record 568 | Rome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=roma
# Processing Record 569 | Kaka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=kaka
# Processing Record 570 | Fort Nelson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=fort%20nelson
# Processing Record 571 | Monrovia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=monrovia
# Processing Record 572 | Manokwari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=manokwari
# Processing Record 573 | Praia da Vitória
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=praia%20da%20vitoria
# Processing Record 574 | Chul'man
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=chulman
# City not found. Skipping...
# Processing Record 575 | West Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=west%20bay
# Processing Record 576 | Zima
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=zima
# Processing Record 577 | Birao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=birao
# Processing Record 578 | Mayumba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=mayumba
# City not found. Skipping...
# Processing Record 579 | Kaabong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=kaabong
# Processing Record 580 | Chifeng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=chifeng
# Processing Record 581 | Qaqortoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=qaqortoq
# Processing Record 582 | Howard Springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=howard%20springs
# Processing Record 583 | Shahrud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=shahrud
# Processing Record 584 | São João da Barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=sao%20joao%20da%20barra
# Processing Record 585 | Paso de Carrasco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=paso%20de%20carrasco
# Processing Record 586 | Jalingo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a03a1efe6eb5098c404cb5636949fc8f&q=jalingo

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Export the city data into a .csv.
weather_df.to_csv("output_data/cities.csv")

# %%
# Build dataFrame with url query    
weather_dict = {
    "City": city_name,
    "Cloudiness":cloudiness, 
    "Country":country,
    "Date":date, 
    "Humidity": humidity,
    "Lat":lat, 
    "Lng":lng, 
    "Max Temp": max_temp,
    "Wind Speed":wind_speed
}

# Create a data frame from dictionary
weather_data = pd.DataFrame.from_dict(weather_dict, orient="index")
weather_df = weather_data.transpose()
weather_df
# Out:
#                   City Cloudiness Country        Date Humidity    Lat     Lng  \
# 0             Hokitika          0      NZ  1599539044       69 -42.72  170.97
# 1            Busselton         85      AU  1599539045       71 -33.65  115.33
# 2              Kavieng          5      PG  1599539046       74  -2.57   150.8
# 3             Cidreira        100      BR  1599538501       92 -30.18  -50.21
# 4              Camacha         40      PT  1599538457       83  33.08  -16.33
# ..                 ...        ...     ...         ...      ...    ...     ...
# 581     Howard Springs         75      AU  1599539546       13  -12.5  131.05
# 582            Shahrud         63      IR  1599539547       18  36.42   54.98
# 583  São João da Barra         40      BR  1599539549       87 -21.64  -41.05
# 584   Paso de Carrasco         17      UY  1599539549       76 -34.86  -56.05
# 585            Jalingo         30      NG  1599539550       91   8.88   11.37
#
#     Max Temp Wind Speed
# 0      53.55       6.98
# 1         63          7
# 2      84.81      11.01
# 3      58.55      17.34
# 4       71.6      13.87
# ..       ...        ...
# 581       97      12.75
# 582    79.23       5.39
# 583    72.86      19.08
# 584     48.2        4.7
# 585    71.62       1.81
#
# [586 rows x 9 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# removing null values to avoid errors  
weather_df.dropna(inplace = True)  

perc =[.50, .75, .100] 
include =['object', 'float', 'int'] 
  
# Display stats of weather data and inspect values 
stats_df = weather_df.describe(percentiles = perc, include = include) 
stats_df
# Out:
#         City  Cloudiness Country        Date  Humidity     Lat    Lng  \
# count    586         586     586         586       586  586.00  586.0
# unique   586          92     116         389        91  573.00  576.0
# top     Poum           0      RU  1599539126        93   65.97  135.6
# freq       1          84      68           4        27    2.00    2.0
#
#         Max Temp  Wind Speed
# count      586.0      586.00
# unique     350.0      307.00
# top         73.4        3.36
# freq        13.0       24.00

# %%
#  Get the indices of cities that have humidity over 100%.
find_first = []
for i in range(len(weather_df)):
    if (weather_df.loc[i, 'Humidity'] == False and df.loc[i+100, 'Humidity'] == True):
        find_first.append(i+1)
find_first
# Out:
# []

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
outliers = weather_df.Humidity > 100 
pd.DataFrame(outliers)

# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
# clean_city_data = outliers.loc[outliers["Humidity"] > 100, "Cities with +100 Humidity"] = 'True'
# weather_df.loc[weather_df['Humidity'] > 100, 'Cities with less Humidity'] = 'False' 
# clean_city_data
# Out:
#      Humidity
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# ..        ...
# 581     False
# 582     False
# 583     False
# 584     False
# 585     False
#
# [586 rows x 1 columns]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_df["Lat"], weather_df["Max Temp"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Max_Temp_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_df["Lat"], weather_df["Humidity"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Humidity_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_df["Lat"], weather_df["Cloudiness"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Cloudiness_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_df["Lat"], weather_df["Wind Speed"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Wind_Speed_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
#Create variables and DataFrame for linear regression
northern_df = weather_df.loc[pd.to_numeric(weather_df["Lat"]).astype(float) > 0, :]
southern_df = weather_df.loc[pd.to_numeric(weather_df["Lat"]).astype(float) < 0, :]
northern_df
# Out:
#              City Cloudiness Country        Date Humidity    Lat     Lng  \
# 4         Camacha         40      PT  1599538457       83  33.08  -16.33
# 5          Hasaki         20      JP  1599539047       55  35.73  140.83
# 10         Broome          1      US  1599538513       77  42.25  -75.83
# 13       Straumen         75      NO  1599539052       87  63.87    11.3
# 14   Longyearbyen         20      SJ  1599539052       84  78.22   15.64
# ..            ...        ...     ...         ...      ...    ...     ...
# 578       Kaabong         44      UG  1599539545       84   3.48   34.15
# 579       Chifeng         54      CN  1599539546       42  42.27  118.96
# 580      Qaqortoq         10      GL  1599539546       72  60.72  -46.03
# 582       Shahrud         63      IR  1599539547       18  36.42   54.98
# 585       Jalingo         30      NG  1599539550       91   8.88   11.37
#
#     Max Temp Wind Speed
# 4       71.6      13.87
# 5         93      14.99
# 10        66       5.82
# 13        55      17.22
# 14      33.8       8.05
# ..       ...        ...
# 578    64.51       5.19
# 579    73.45      17.02
# 580     39.2       2.24
# 582    79.23       5.39
# 585    71.62       1.81
#
# [403 rows x 9 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_df['Max Temp']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Lat')
plt.ylabel('Max Temperature (F)')
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a negative correlation.")
print("In the nothern hemisphere, as you move away from the equator the temperature decreases.")
plt.savefig("output_data/Northern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
plt.show()
# Out:
# Regression line equation is: y = -0.56x + 88.34
# The r-squared is: -0.7628832094371074
# The regression displays a negative correlation.
# In the nothern hemisphere, as you move away from the equator the temperature decreases.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_df['Max Temp']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.title('Southern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a positive correlation.")
print("In the southern hemisphere, as you get closer to the equator the temperature increases.")
plt.savefig("output_data/Southern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
plt.show()
# Out:
# Regression line equation is: y = 0.59x + 80.75
# The r-squared is: 0.6341510523806688
# The regression displays a positive correlation.
# In the southern hemisphere, as you get closer to the equator the temperature increases.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_df['Humidity']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.") 
plt.savefig("output_data/Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
plt.show()
# Out:
# Regression line equation is: y = -0.08x + 75.08
# The r-squared is: -0.0799989704411452
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_df['Humidity']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.savefig("output_data/Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
plt.show()
# Out:
# Regression line equation is: y = 0.09x + 71.1
# The r-squared is: 0.05560712210877677
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_df['Cloudiness']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.savefig("output_data/Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
plt.show()
# Out:
# Regression line equation is: y = -0.07x + 53.81
# The r-squared is: -0.036058947844212874
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_df['Cloudiness']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.savefig("output_data/Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
plt.show()
# Out:
# Regression line equation is: y = 0.18x + 43.45
# The r-squared is: 0.06461011068512189
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_df['Wind Speed']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.savefig("output_data/Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression.png")
plt.show()
# Out:
# Regression line equation is: y = 0.06x + 5.33
# The r-squared is: 0.23510645071694092
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_df['Wind Speed']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.savefig("output_data/Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression.png")
plt.show()
# Out:
# Regression line equation is: y = -0.06x + 6.85
# The r-squared is: -0.14127741047036804
# The regression does not display much of a correlation between the data sets.
